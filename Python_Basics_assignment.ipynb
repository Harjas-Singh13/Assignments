# %% [markdown]
# 1.	Explain the key feature of python that make it popular choice for programming?
#
# --> Simple and readable: - Python is very easy to be learned and read. As most of the keywords and the commands that are used in English language itself and are easy to understand the meaning of the keyword from the words itself.
# 	Object Oriented and Procedural Programming: - Python supports both object oriented and procedural programming paradigms, offering various functions and flexibility to the users to use the code in any way they want.
#
# -->Number of libraries: - There are a lot number of libraries that python have and make the work easy for the users to achieve the task that they are using and writing the code for.
#
# -->	Cross platform: - Python can be used in every platform despite of being Windows, macOS and even in Linux too.
#
# --> Open Source: - Being open source, python encourages large community involvement, allowing everyone despite of any age group or any knowledge to continuously work on improving the language and offering support.
#
# -->Embeddable and Extensible: - Python is embeddable, allowing developer to include Python code within code written in other language.
#
# 2.	Describe the role of predefined keywords in Python and provide examples of how they are used in a program.
#
# --> Python keywords are reserved words that hold a specific meaning in the language and are used in the code/ program to achieve an output or give some meaning to the code so that the output can be achieved. Python keywords are basically used to define something in a code/program so that the system have an idea what needs to be done.
#
# --> For Example: -
#
# Control Flow: - There are three keywords that are widely used in control flow that are if, else, and elif.
# Syntax: -
#
# if condition:   # code to execute if condition is True
#
# elif another_condition: # code to execute if aniother_condition is True
#
# else: # code to execute if all conditions above are False
#
# For example: -
#
# a = 10
#
# b = 5
#
# if a > b:
#
# 	print(“a is greater than b”)
#
# elif a == b:
#
# 	print(“a is equal to b”)
#
# else:
#
# 	print(“b is greater than a”)
#
# 3.	Compare and contrast mutable and immutable objects in Python with examples?
#
# -->	Mutable Objects: - Mutable objects can be modified after they are created.
# Examples: - Lists, dictionaries, sets.
# When the mutable objects are changed, the content of the original object that was created is changed, and the object itself remains the same. This means that if there is a reference to the object present, it will see the changes.
# Example: -
# my_list = [1,2,3]
# my_list.append(4) #Modifies the list in place
# print(my_list) #Output: - [1,2,3,4]
#
# --> Immutable Objects: - Immutable objects can not be modified once they have been defined and created.
#
# o	Examples: - Tuples, strings.
#
# Any operation that seems to modify an immutable object will instead create a new object leaving the original unchanged, or else it will give an error.
#
# Example: -
#
# my_tuple(1,2,3)
#
# my_tuple[0] = 4 #This will give an error
#
# new_tuple = my_tuple +(4,) #Creates a new tuple
#
# print(new_tuple) #Output:- (1,2,3,4)
#
#
# 4.	Discuss the different types of operators used in Python and provide examples of how they are used?
# --> There are 6 types of operators that are used in Python. That are as following: -
#
# i.	Arithmetic operators.
#
# ii.	Comparison operators.
#
# iii.	Logical operators.
#
# iv.	Bitwise operators.
#
# v.	Assignment operators.
#
# vi.	Identity operators and Membership operators.
#
# •	Arithmetic operators: - These are used to perform basic mathematical operations, like addition, subtraction, multiplication, division, modulus and etc.
#
# For example: -
#
# a = 2 + 3
#
# 	print(a)
#
# b = 5 - 2
#
# 	print(b)
#
# •	Comparison operators: - Comparison operator in Python refers to comparing between two variables, data or anything and then giving the value in True or False. There are 6 types of comparison operators that are widely used that are: -
#
# o	> Greater than: True if the left operand is greater than the right one. For example: - x > y
#
# o	< Less Than: - True if the left operand is lesser than the right one. For example: x < y
#
# o	== Equal to: - True if both the operands are equal. For example: - a == b
#
# o	! = Not equal to: - True if operands are not equal. For example: - a != b
#
# o	>= Greater than or equal to: - True if the left operand is greater than or equal to the right operand. For example: - e >= f
#
# o	<= Less than or equal to: - True if the left operand is lesser than or equal to the right operand. For example: - e <= f.
#
# •	Logical operators: - Logical operators in python are used to combine conditional statements. As in when trying to create a simple logic in code these operators help out in a big manner to make it easy. There are three type of logical operators that are: - AND, OR, NOT.
#
# For example :-
# x = True
# y = False
#
# o	AND operator: - It is True if both the operands are True. For example: - x and y. Output: - False
#
# o	OR operator: - True if either of the operand is True. For example: - x or y.
# Output: - True
#
# o	NOT operator: - True if operand is false. For example: - not x
# Output: - False
#
# •	Bitwise operators: - Bitwise operators act on bits and perform bit-by-bit operations. These are used to operate on binary numbers that are understandable by the system. There are 6 types of bitwise operators in python that are as follows: -
#
# Operator	Description	Syntax
#
# &	Bitwise AND	x & y
#
# '|' 	Bitwise OR	x | y
#
# '~'	Bitwise NOT	x ~ y
#
# '^'	Bitwise XOR	x ^ y
#
# '>>' 	Bitwise right shift	x >> y
#
# '<<' 	Bitwise left shift	x << y
#
# •	Assignment Operators: - Assignment operators in Python are used to assign some value to each other. Following are some assignment operators that are used in Python.
#
# =	Assign the value of the right side of the expression to the left side of the operand	a = b + c
#
# +=	Add AND: Add right side operand with left side operand and then assign the new value to the left side operand	a+=b  a = a + b
#
# -=	Subtract AND: Subtract right operand from left operand and then assign to the left operand. 	a-=b  a = a - b
#
# *=	Multiply AND: Multiply right operand with the left operand and then assign it to left operand	a*=b  a = a * b
#
# /=	Divide AND: Divide left operand with right operand and then assign to left operand	a/=b      a=a/b
#
# %=	Modulus AND: Takes modulus using left and right operands and assign the result to left operand	a%=b     a=a%b
#
# //=	Divide(floor) AND: Divide left operand with right operand and then assign the value(floor) to left operand	a//=b     a=a//b
#
# **= Exponent AND: It will calculate exponent (raise power) value using operands and assign value to left operand
#
# 5.	Explain the concept of type casting in Python with examples.
#
# -->Type Casting: - Type Casting is the method to convert the Python variable datatype into a certain data type in order to perform the required operation by users. In this article, we will see the various techniques for typecasting. There can be two types of Type Casting in Python:
#
# o	Python Implicit Type Conversion: - Implicit type casting, also known as implicit type conversion, occurs when the compiler automatically converts data from one type to another without the need for explicit instructions from the programmer. This conversion is performed when a value of one data type is assigned to a variable of another data type, and the target type can safely represent the source value without loss of precision or data.
#
# o	Python Explicit Type Conversion: - In this method, Python needs user involvement to convert the variable data type into the required data type.
#
# o	Examples of Explicit Type Casting in Python
#
# o	Int (): Python Int () function take float or string as an argument and returns int type object.
#
# o	float (): Python float () function take int or string as an argument and return float type object.
#
# o	str (): Python str () function takes float or int as an argument and returns string type object.
#
# 6.	How do conditional statements work in Python? Illustrate with examples.
#
# -->Conditional Statements are statements in Python that provide a choice for the control flow based on a condition. It means that the control flow of the Python program will be decided based what is the output of the condition. There are 4 types of conditional statements that are as follows: -
#
# o	If Conditional Statement: - If statement is used when we want to give our code an option that if it is true execute this or else if it not true it will not show any error but it will not execute.
#
# For example: -
#
# if 10 > 5:
#
#     print("10 greater than 5")
#
# o	If else Conditional Statement: - It is same as If condition but here we have an option of adding else which means if the condition is false then print the statement that is given after else.
#
# x = 5
#
# if x == 4:
#
# 	print(“True”)
#
# else:
#
# 	print(“False”)
#
# o	Nested If else Conditional Statement: - Nested if else means an if-else statement inside another if statement. Or in simple words first, there is an outer if statement, and inside it another if else statement is present and such type of statement is known as nested if statement.
#
# Age = 50
#
# If age == 50:
#
# 	Print(“Welcome to the Oldage”)
#
# Else:
#
# 	If age == 40:
#
# 		Print(“Welcome to the Forties”)
#
# 	Else:
#
# 		If age == 18:
#
# 			Print(“Welcome to Adulthood”)
#
# 		Else:
#
# 			Print(“Newborn”)
#
# o	If elif else Conditional statement: - The if statements are executed from the top down. As soon as one of the conditions controlling the if is true, the statement associated with that if is executed, and the rest of the ladder is bypassed. If none of the conditions is true, then the final “else” statement will be executed. In this statement the interpreter starts reading the statement s from top to bottom the moment any condition is correct and run all others are left out and output is given.
#
# e = int(input(“Please enter any number”))
#
# if  e > 10:
#
# 	print(“e is greater than 10”)
#
# elif e < 10:
#
# 	print(“e is less than 10”)
#
# else:
#
# 	print(“Try another number”)
#
# 7.	Describe the different types of loops in Python and their use cases with examples.
#
# --> There are different types of loops in Python that are as follows: -
#
# o	WHILE Loop: - In Python the while loop is used to execute a block of statement repeatedly again and again until the condition is met. Once the condition is false it comes out of the code and till the conditions were getting met the code will get executed.
#
# For example: -
#
# a = 0
#
# while(a<=3):
#
# 	a = a+1
#
# 	print(“Hello World”)
#
# This code will print Hello World three times in the row.
#
# o	FOR Loop: - In Python, the for loop is used to iterate over a sequence (such as a list, tuple, string, or dictionary) or any iterable object.
#
# For example: -
#
# n = 5
#
# for i in range(0,n):
#
#     print(i)
#
# The code uses a Python for loop that iterates over the values from 0 to 4 (not including 5), as specified by the range(0,n). It will print the values of ‘i' in each iteration of the loop.
